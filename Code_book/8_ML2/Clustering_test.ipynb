# %%
from numpy import unique
from numpy import where
from matplotlib import pyplot
import pandas as pd
import csv
import numpy as np

# %%
class Unit:
    def __init__(self, unit,x,y,food,frozen_food,office_supplies,furniture,daily_necessities):
        self.unit=unit
        self.x=x
        self.y=y
        self.food=food
        self.frozen_food=frozen_food
        self.office_supplies=office_supplies
        self.furniture=furniture
        self.daily_necessities=daily_necessities

units = []
with open("neo result.csv") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        unit = row['unit']
        x=row['x']
        y=row['y']
        food=row['food']
        frozen_food = row['frozen food']
        office_supplies=row['office supplies']
        furniture=row['furniture']
        daily_necessities=row['daily necessities']
        units.append(Unit(unit,x,y,food,frozen_food,office_supplies,furniture,daily_necessities))
print(len(units))
# Out:
# 27510

# %%
neounits=[]
for u in units:
    if not (float(u.food)==0 and float(u.frozen_food)==0 and float(u.office_supplies)==0 and float(u.furniture)==0 and float(u.daily_necessities)==0):
        neounits.append(u)
X=[]
Y=[]
for u in neounits:
    X.append(u.x)
    Y.append(u.y)

print(len(neounits))
for u in neounits[0:10]:
    print(u.x+' '+u.y)
# Out:
# 4262
# 76 13
# 77 13
# 62 14
# 76 14
# 77 14
# 78 14
# 79 14
# 108 14
# 62 15
# 63 15

# %%
df=pd.DataFrame({'x':X,'y':Y})

df.to_csv('neo location.csv',index=False)

# define the dataset
file = pd.read_csv( 'neo location.csv')
x_y = np.array(file)

# %%
class Color:
    def __init__(self, name,color):
        self.unit=name
        self.color=color

colors = []
with open("color.csv") as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        name = row['name']
        color= row['color']
        colors.append(Color(name,color))

# %%
from random import shuffle
from random import sample
shuffle(colors)

colorbox=[]
colorname=[]
for c in colors:
    colorname.append(c.unit)
    colorbox.append(c.color)

from pandas import DataFrame
df=DataFrame({'name':colorname,'color':colorbox})
df.to_csv('neo color box.csv',index=False)

# %%
# affinity propagation clustering
from sklearn.cluster import AffinityPropagation

# define the model
model = AffinityPropagation(damping=0.7)
# fit the model
model.fit(file)
# assign a cluster to each example
yhat = model.predict(file)
# retrieve unique clusters
clusters = unique(yhat)
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("affinity propagation clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# agglomerative clustering
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=10)
# fit model and predict clusters
yhat = model.fit_predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

n = 10
# create scatter plot for samples from each cluster
for cluster,c in zip(clusters,colorbox[0:n]):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',color=c,s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("agglomerative clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# birch clustering
from sklearn.cluster import Birch

# define the model
model = Birch(threshold=0.01, n_clusters=10)
# fit the model
model.fit(file)
# assign a cluster to each example
yhat = model.predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

n = 10
# create scatter plot for samples from each cluster
for cluster,c in zip(clusters,colorbox[0:n]):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',color=c,s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("birch clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# dbscan clustering
from sklearn.cluster import DBSCAN

# define the model
model = DBSCAN(eps=0.30, min_samples=9)
# fit model and predict clusters
yhat = model.fit_predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)



font={'color':'black','size':120,'family':'arial'}
pyplot.title("dbscan clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# k-means clustering
from sklearn.cluster import KMeans

# define the model
n=10
model = KMeans(n_clusters=n)
# fit the model
model.fit(file)
# assign a cluster to each example
yhat = model.predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("k-means clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# mini-batch k-means clustering
from sklearn.cluster import MiniBatchKMeans

# define the model
model = MiniBatchKMeans(n_clusters=10)
# fit the model
model.fit(file)
# assign a cluster to each example
yhat = model.predict(file)
# retrieve unique clusters
clusters = unique(yhat)
# Out:
# C:\Users\qq809\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:887: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 4096 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)


font={'color':'black','size':120,'family':'arial'}
pyplot.title("mini-batch k-means clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# mean shift clustering
from sklearn.cluster import MeanShift

# define the model
model = MeanShift()
# fit model and predict clusters
yhat = model.fit_predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴


# create scatter plot for samples from each cluster
for cluster in clusters:
	# get row indexes for samples with this cluster
	row_ix = where(yhat == cluster)
	# create scatter of these samples
	pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("mini-batch k-means clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# optics clustering
from sklearn.cluster import OPTICS

# define the model
model = OPTICS(eps=0.8, min_samples=10)
# fit model and predict clusters
yhat = model.fit_predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("optics clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# spectral clustering
from sklearn.cluster import SpectralClustering

# define the model
model = SpectralClustering(n_clusters=10)
# fit model and predict clusters
yhat = model.fit_predict(file)
# retrieve unique clusters
clusters = unique(yhat)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b049fff4bec9> in <module>
#       5 model = SpectralClustering(n_clusters=10)
#       6 # fit model and predict clusters
# ----> 7 yhat = model.fit_predict(file)
#       8 # retrieve unique clusters
#       9 clusters = unique(yhat)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py in fit_predict(self, X, y)
#     566             Cluster labels.
#     567         """
# --> 568         return super().fit_predict(X, y)
#     569
#     570     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_predict(self, X, y)
#     581         # non-optimized default implementation; override when a better
#     582         # method is possible for a given clustering algorithm
# --> 583         self.fit(X)
#     584         return self.labels_
#     585
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py in fit(self, X, y)
#     533
#     534         random_state = check_random_state(self.random_state)
# --> 535         self.labels_ = spectral_clustering(self.affinity_matrix_,
#     536                                            n_clusters=self.n_clusters,
#     537                                            n_components=self.n_components,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_spectral.py in spectral_clustering(affinity, n_clusters, n_components, eigen_solver, random_state, n_init, eigen_tol, assign_labels, verbose)
#     269     # and should be kept for spectral clustering (drop_first = False)
#     270     # See spectral_embedding documentation.
# --> 271     maps = spectral_embedding(affinity, n_components=n_components,
#     272                               eigen_solver=eigen_solver,
#     273                               random_state=random_state,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py in spectral_embedding(adjacency, n_components, eigen_solver, random_state, eigen_tol, norm_laplacian, drop_first)
#     277             laplacian *= -1
#     278             v0 = _init_arpack_v0(laplacian.shape[0], random_state)
# --> 279             _, diffusion_map = eigsh(
#     280                 laplacian, k=n_components, sigma=1.0, which='LM',
#     281                 tol=eigen_tol, v0=v0)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1685     with _ARPACK_LOCK:
#    1686         while not params.converged:
# -> 1687             params.iterate()
#    1688
#    1689         return params.extract(return_eigenvectors)
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in iterate(self)
#     558             else:
#     559                 Bxslice = slice(self.ipntr[2] - 1, self.ipntr[2] - 1 + self.n)
# --> 560                 self.workd[yslice] = self.OPa(self.workd[Bxslice])
#     561         elif self.ido == 2:
#     562             self.workd[yslice] = self.B(self.workd[xslice])
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\interface.py in matvec(self, x)
#     227             raise ValueError('dimension mismatch')
#     228
# --> 229         y = self._matvec(x)
#     230
#     231         if isinstance(x, np.matrix):
#
# ~\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py in _matvec(self, x)
#     940
#     941     def _matvec(self, x):
# --> 942         return lu_solve(self.M_lu, x)
#     943
#     944
#
# ~\anaconda3\lib\site-packages\scipy\linalg\decomp_lu.py in lu_solve(lu_and_piv, b, trans, overwrite_b, check_finite)
#     143
#     144     getrs, = get_lapack_funcs(('getrs',), (lu, b1))
# --> 145     x, info = getrs(lu, piv, b1, trans=trans, overwrite_b=overwrite_b)
#     146     if info == 0:
#     147         return x
#
# KeyboardInterrupt:

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("optics clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()

# %%
# gaussian mixture clustering
from sklearn.mixture import GaussianMixture

# define the model
model = GaussianMixture(n_components=10)
# fit the model
model.fit(file)
# assign a cluster to each example
yhat = model.predict(file)
# retrieve unique clusters
clusters = unique(yhat)

# %%
ax = pyplot.gca()                                 #获取到当前坐标轴信息
ax.xaxis.set_ticks_position('top')                #将X坐标轴移到上面
ax.invert_yaxis()                                 #反转Y坐标轴

# create scatter plot for samples from each cluster
for cluster in zip(clusters):
    # get row indexes for samples with this cluster
    row_ix = where(yhat == cluster)
    # create scatter of these samples
    pyplot.scatter(x_y[row_ix, 0], x_y[row_ix, 1],marker='s',s=1600)

font={'color':'black','size':120,'family':'arial'}
pyplot.title("gaussian mixture clustering", fontsize=120)
pyplot.rcParams['figure.figsize'] = (210, 130)
pyplot.show()
